# %%
print("Omraj Sharma")
# Out:
# Omraj Sharma

# %%
a = 10
b = 5
c = a / b
print(c)
# Out:
# 2.0

# %%
'''
class 1 - INTRODUCTION
'''
# input from the users
# a = int(input("Enter a number"))
# print(10 / a)

# bill = 100
# final_bill = 100 * (1 - 12 / 100)
# print(final_bill)

# abc = 10
# print(abc)

# single line comment ex - calculation of pi program
'''
MULTI
LINE COMMENTS
'''

"""
MULTI
LINE COMMENTS
"""

print("hello world")
# Out:
# hello world

# %%
'''
class 2 - Data Types, Operators
'''


'''
DATA TYPES 
'''

# PRIMITIVE DATA TYPES (FUNDAMENTAL DATA TYPES) - You can't break them further

# INTEGER
# age = 10
# print(age)

# FLOAT
# pi = 3.14
# print(pi)

# STRING - WORD, CHARACTER, SENTENCE
# name = "omraj"
# hobby = "playing guitar"
# favAlpha = '100'
# print(name)
# print(hobby)
# print(type(favAlpha))

# BOOLEAN - True, False
# passed = True
# print(passed)

# None - nothing
# car = None
# print(car)

# COMPLEX - real + imaginary
# z = 2 + 3j

# DERIVED DATA TYPES - are made of primitive data types

# LIST
# randomList = ["apple", "mango", "grapes", "grapes", 1, 2, 3, 4, True]
# print(randomList)

# TUPLE - FIXED LIST - can't add / remove
# randomList = ("apple", "mango", "grapes", "grapes", 1, 2, 3, 4, True)
# print(randomList)

# SET - list of unique values
# lucky_numbers = {1,2,3,3,3,3,3,3,4,5}
# print(lucky_numbers)

# FROZENSET - FIXED SET - can't add / remove
# frozen = frozenset([1,2,3,3,3,3,3,4,5])
# print(frozen)

# DICTIONARY - { key : value }
# student_marks = {
#     "Rahul": 98,
#     "Utkarsh": 99,
#     "Om": [92, 94]
# }
# print(student_marks)


'''
ARITHEMETIC OPERATORS 
'''
# a = 10
# b = 5
# print(a + b)
# print(a - b)
# print(a * b)
# print(a / b)
# a = 10
# b = 3
# print(a % 3)  # remainder
# print(a // b) # fllor
# print(a ** b) # exponentiation

'''
COMPARISON OPERATOR
output - True/False - boolean
'''
# a = 10
# b = 5
# print(a == b)
# print(a != b)
# print(a > b)
# print(a >= b)
# print(a < b)
# print(a <= b)

'''
ASSIGNMENT OPERATOR -
'''
# a = 10
# print(a)
# a = 12
# print(a)
# a += 10 # a = a + 10
# print(a)
# a -= 2 # a = a - 2
# print(a)
# a *= 2 # a = a * 2
# print(a)
# a %= 6 # a = a % 3
# print(a)
# a **= 2 # a = a ** 2
# print(a)
# a //= 3 # a = a // 3
# print(a)

'''
LOGICAL OPERATORS 
- not
- and - multiply
- or -  addition

True - 1
False - 0
'''

# print(not True)
# print(not False)
# print(False and False)
# print(False and True)
# print(True and True)
# print(True and False)
# print(False or False)
# print(False or True)
# print(True or True)
# print(True or False)
# print(10 > 5 and 10 < 9)

'''
MEMBERSHIP OPERATOR
in, not in
'''
# print('a' in 'cat')
# print('b' in 'cat')
# print('om' in ['om', 'shyam'])
# print('ram' in ['om', 'shyam'])
# print('om' in ['om', 'shyam'])
# print('ram' not in ['om', 'shyam'])

'''
INDETITY OPERATOR
'''
# a = [1,2,3]
# b = [1,2,3]
# c = a
# print( a == b )  # value
# print( a is b )  # memory location
# print( a is c )

'''
BITWISE OPERATOR - works on bits (0,1)
'''
# print(5 & 3)
# print(5 | 3)
# print(5 ^ 3)
# print(5 << 1)
# print(5 << 2)
# print(5 >> 1)
# print(5 >> 2)
# Out:
# 1
# 7
# 6
# 10
# 20
# 2
# 1

# %%
'''
NUMPY - 
introduction - https://www.w3schools.com/python/numpy/numpy_intro.asp 
list - more space, numpy - less space -> faster
no type checking in numpy
have contigeous memory
benefits - SIMD vector processing
effective cache utilisation
lots more - multiple array, 
application - matlab replacement, plotting, backend, machine learning, 

https://www.youtube.com/watch?v=QUT1VHiLmmI&ab_channel=freeCodeCamp.org
https://github.com/KeithGalli/NumPy/blob/master/NumPy%20Tutorial.ipynb
'''
import numpy as np
a = np.array([1,2,3,4,5])
