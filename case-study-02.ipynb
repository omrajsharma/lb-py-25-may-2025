# %% [markdown]
# # Case Study 02

# %% [markdown]
# Airbnb

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('airbnb.csv')

# %%
df.head(2)
# Out:
#       id                         listing_url  \
# 0  11156  https://www.airbnb.com/rooms/11156
# 1  12351  https://www.airbnb.com/rooms/12351
#
#                                 name  host_id host_name host_since  \
# 0               An Oasis in the City    40855   Colleen   23/09/09
# 1  Sydney City & Harbour at the door    17061    Stuart   14/05/09
#
#   host_is_superhost host_identity_verified                       street  \
# 0                 t                      f  Potts Point, NSW, Australia
# 1                 f                      t      Pyrmont, NSW, Australia
#
#           city  ... monthly_price security_deposit cleaning_fee  \
# 0  Potts Point  ...           NaN              NaN          NaN
# 1      Pyrmont  ...           NaN           $0.00       $55.00
#
#    guests_included  extra_people has_availability number_of_reviews  \
# 0                1        $0.00                 1               177
# 1                2      $395.00                 1               468
# ...

# %%
df.shape
# Out:
# (27076, 36)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'country', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'has_availability', 'number_of_reviews',
#        'review_scores_rating', 'instant_bookable', 'cancellation_policy'],
#       dtype='object')

# %%
df['property_type'].head()
# Out:
# 0    Apartment
# 1    Townhouse
# 2        House
# 3    Apartment
# 4    Apartment
# Name: property_type, dtype: object

# %%
df['room_type'].head()
# Out:
# 0       Private room
# 1       Private room
# 2    Entire home/apt
# 3       Private room
# 4        Shared room
# Name: room_type, dtype: object

# %%
df['accommodates'].head()
# Out:
# 0    1
# 1    2
# 2    6
# 3    2
# 4    1
# Name: accommodates, dtype: int64

# %%
df[ ['price', 'weekly_price', 'monthly_price'] ].head()
# Out:
#       price weekly_price monthly_price
# 0   $65.00           NaN           NaN
# 1   $98.00      $800.00            NaN
# 2  $469.00    $3,000.00            NaN
# 3   $63.00           NaN           NaN
# 4   $39.00           NaN           NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27076 entries, 0 to 27075
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      27076 non-null  int64
#  1   listing_url             27076 non-null  object
#  2   name                    27062 non-null  object
#  3   host_id                 27076 non-null  int64
#  4   host_name               27041 non-null  object
#  5   host_since              27041 non-null  object
#  6   host_is_superhost       27041 non-null  object
#  7   host_identity_verified  27041 non-null  object
#  8   street                  27076 non-null  object
#  9   city                    27043 non-null  object
#  10  state                   27067 non-null  object
#  11  country_code            27076 non-null  object
#  12  country                 27076 non-null  object
#  13  latitude                27076 non-null  float64
# ...

# %%
df.head()
# Out:
#       id                         listing_url  \
# 0  11156  https://www.airbnb.com/rooms/11156
# 1  12351  https://www.airbnb.com/rooms/12351
# 2  14250  https://www.airbnb.com/rooms/14250
# 3  14935  https://www.airbnb.com/rooms/14935
# 4  14974  https://www.airbnb.com/rooms/14974
#
#                                      name  host_id host_name host_since  \
# 0                    An Oasis in the City    40855   Colleen   23/09/09
# 1       Sydney City & Harbour at the door    17061    Stuart   14/05/09
# 2                     Manly Harbour House    55948     Heidi   20/11/09
# 3  Eco-conscious Travellers: Private Room    58796     Kevin   30/11/09
# 4     Eco-conscious Traveller: Sofa Couch    58796     Kevin   30/11/09
#
#   host_is_superhost host_identity_verified                       street  \
# 0                 t                      f  Potts Point, NSW, Australia
# 1                 f                      t      Pyrmont, NSW, Australia
# ...

# %%
df.sample(3)
# Out:
#              id                            listing_url  \
# 19733  19707600  https://www.airbnb.com/rooms/19707600
# 6376    8742061   https://www.airbnb.com/rooms/8742061
# 5705    7898195   https://www.airbnb.com/rooms/7898195
#
#                                                     name   host_id  \
# 19733          The Tamarama Beach Hut Near Bondi Parking  28793939
# 6376                          Pent house in North Sydney  45861621
# 5705   Kingsgrove - Fully furnished room in modern house  30392927
#
#         host_name host_since host_is_superhost host_identity_verified  \
# 19733  Ray & Gene    5/03/15                 f                      f
# 6376    Madeleine    5/10/15                 f                      f
# 5705        Simon    1/04/15                 f                      t
#
#                            street        city  ... monthly_price  \
# 19733    Tamarama, NSW, Australia    Tamarama  ...           NaN
# ...

# %%
df['amenities']
# Out:
# 0        {TV,Kitchen,Elevator,"Buzzer/wireless intercom...
# 1        {TV,Internet,Wifi,"Air conditioning","Paid par...
# 2        {TV,Wifi,"Air conditioning",Kitchen,"Pets live...
# 3        {Internet,Wifi,"Wheelchair accessible",Pool,Ki...
# 4        {Internet,Wifi,Pool,Kitchen,Gym,Elevator,"Buzz...
#                                ...
# 27071    {Wifi,Kitchen,"Family/kid friendly",Washer,"Sm...
# 27072    {TV,"Cable TV",Wifi,Pool,Kitchen,"Free street ...
# 27073    {TV,Wifi,"Indoor fireplace",Heating,Washer,"Sm...
# 27074    {TV,Internet,Wifi,"Air conditioning",Pool,Kitc...
# 27075    {TV,Wifi,Kitchen,Heating,"Family/kid friendly"...
# Name: amenities, Length: 27076, dtype: object

# %%
am1 = df['amenities'].iloc[0]
am1
# Out:
# '{TV,Kitchen,Elevator,"Buzzer/wireless intercom",Heating,Washer,"Smoke detector","Fire extinguisher",Essentials,Hangers,"Hair dryer",Iron,"Bed linens","Extra pillows and blankets",Microwave,Refrigerator,Dishwasher,"Dishes and silverware","Cooking basics",Stove,"Single level home","Patio or balcony","Garden or backyard"}'

# %%
am1.split(',')
# Out:
# ['{TV',
#  'Kitchen',
#  'Elevator',
#  '"Buzzer/wireless intercom"',
#  'Heating',
#  'Washer',
#  '"Smoke detector"',
#  '"Fire extinguisher"',
#  'Essentials',
#  'Hangers',
#  '"Hair dryer"',
#  'Iron',
#  '"Bed linens"',
#  '"Extra pillows and blankets"',
#  'Microwave',
#  'Refrigerator',
#  'Dishwasher',
#  '"Dishes and silverware"',
#  '"Cooking basics"',
#  'Stove',
#  '"Single level home"',
#  '"Patio or balcony"',
#  '"Garden or backyard"}']

# %%
len(am1.split(','))
# Out:
# 23

# %%
def get_amenities_count(amenities):
    return len(amenities.split(','))

# %%
df['amenities'].apply(get_amenities_count)
# Out:
# 0        23
# 1        29
# 2        20
# 3        17
# 4         9
#          ..
# 27071     9
# 27072    20
# 27073    25
# 27074    15
# 27075    31
# Name: amenities, Length: 27076, dtype: int64

# %%
# create a new column 
df['amenities_count'] = df['amenities'].apply(get_amenities_count)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'country', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'has_availability', 'number_of_reviews',
#        'review_scores_rating', 'instant_bookable', 'cancellation_policy',
#        'amenities_count'],
#       dtype='object')

# %%
# Look up for duplicate row
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27071     True
# 27072     True
# 27073     True
# 27074     True
# 27075     True
# Length: 27076, dtype: bool

# %%
df[df.duplicated()]
# Out:
#              id                            listing_url  \
# 27070  22151172  https://www.airbnb.com/rooms/22151172
# 27071  16444390  https://www.airbnb.com/rooms/16444390
# 27072  14829119  https://www.airbnb.com/rooms/14829119
# 27073  15918138  https://www.airbnb.com/rooms/15918138
# 27074   8977894   https://www.airbnb.com/rooms/8977894
# 27075  17642461  https://www.airbnb.com/rooms/17642461
#
#                                                     name    host_id  \
# 27070          Sgl rm close to shop/restaurant/transport  159933426
# 27071  1min walk from Coogee beach - awesome double room   67102419
# 27072         Bronte Beach House : Views & Swimming Pool     113874
# 27073                 Brickfield Hill - The Ensuite Room   82600141
# 27074                    Mosman Masterpiece by the Beach   46912165
# 27075    Perfectly located comfortable 3 bedroom terrace   11101996
#
#                        host_name host_since host_is_superhost  \
# ...

# %%
df[df.duplicated(keep=False)] # original record + duplicate
# Out:
#              id                            listing_url  \
# 6628    8977894   https://www.airbnb.com/rooms/8977894
# 12829  14829119  https://www.airbnb.com/rooms/14829119
# 14305  15918138  https://www.airbnb.com/rooms/15918138
# 15788  16444390  https://www.airbnb.com/rooms/16444390
# 17239  17642461  https://www.airbnb.com/rooms/17642461
# 25249  22151172  https://www.airbnb.com/rooms/22151172
# 27070  22151172  https://www.airbnb.com/rooms/22151172
# 27071  16444390  https://www.airbnb.com/rooms/16444390
# 27072  14829119  https://www.airbnb.com/rooms/14829119
# 27073  15918138  https://www.airbnb.com/rooms/15918138
# 27074   8977894   https://www.airbnb.com/rooms/8977894
# 27075  17642461  https://www.airbnb.com/rooms/17642461
#
#                                                     name    host_id  \
# 6628                     Mosman Masterpiece by the Beach   46912165
# 12829         Bronte Beach House : Views & Swimming Pool     113874
# ...

# %%
rows_to_delete = df[df.duplicated()].index

# %%
rows_to_delete
# Out:
# Index([27070, 27071, 27072, 27073, 27074, 27075], dtype='int64')

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#              id                            listing_url  \
# 0         11156     https://www.airbnb.com/rooms/11156
# 1         12351     https://www.airbnb.com/rooms/12351
# 2         14250     https://www.airbnb.com/rooms/14250
# 3         14935     https://www.airbnb.com/rooms/14935
# 4         14974     https://www.airbnb.com/rooms/14974
# ...         ...                                    ...
# 27065  22708135  https://www.airbnb.com/rooms/22708135
# 27066  22708238  https://www.airbnb.com/rooms/22708238
# 27067  22709306  https://www.airbnb.com/rooms/22709306
# 27068  22709315  https://www.airbnb.com/rooms/22709315
# 27069  22709659  https://www.airbnb.com/rooms/22709659
#
#                                                     name    host_id host_name  \
# 0                                   An Oasis in the City      40855   Colleen
# 1                      Sydney City & Harbour at the door      17061    Stuart
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude  accommodates  \
# count  2.707000e+04  2.707000e+04  27070.000000  27070.000000  27070.000000
# mean   1.402672e+07  4.692847e+07    -33.862368    151.210667      3.383598
# std    6.520952e+06  4.525669e+07      0.072260      0.079451      2.196864
# min    1.115600e+04  8.346000e+03    -34.135212    150.644964      1.000000
# 25%    9.083668e+06  1.108913e+07    -33.897603    151.184472      2.000000
# 50%    1.544074e+07  3.016545e+07    -33.883064    151.223242      2.000000
# 75%    2.015561e+07  6.754591e+07    -33.831850    151.264888      4.000000
# max    2.270966e+07  1.674985e+08    -33.389728    151.339811     16.000000
#
#           bathrooms      bedrooms          beds   square_feet  \
# count  27048.000000  27062.000000  27037.000000    256.000000
# mean       1.352337      1.614071      2.012169    421.453125
# std        0.664092      1.109725      1.526399   1573.511992
# ...

# %%
df[df['bathrooms'] == 0]
# Out:
#              id                            listing_url  \
# 1232    2064031   https://www.airbnb.com/rooms/2064031
# 1373    2257635   https://www.airbnb.com/rooms/2257635
# 1934    3334584   https://www.airbnb.com/rooms/3334584
# 2307    4033572   https://www.airbnb.com/rooms/4033572
# 2420    4184110   https://www.airbnb.com/rooms/4184110
# ...         ...                                    ...
# 24923  22069561  https://www.airbnb.com/rooms/22069561
# 25600  22218527  https://www.airbnb.com/rooms/22218527
# 25769  22265628  https://www.airbnb.com/rooms/22265628
# 25993  22309457  https://www.airbnb.com/rooms/22309457
# 26636  22485646  https://www.airbnb.com/rooms/22485646
#
#                                                     name    host_id  \
# 1232      Bondi Large Room w/- Private access to balcony   10561496
# 1373                      Twin Shared Room in Uni Campus   11279706
# 1934                                           Bondi Pad    3611086
# ...

# %%
df[df['bedrooms'] == 0]
# Out:
#              id                            listing_url  \
# 16        63795     https://www.airbnb.com/rooms/63795
# 128      348891    https://www.airbnb.com/rooms/348891
# 147      387130    https://www.airbnb.com/rooms/387130
# 159      405432    https://www.airbnb.com/rooms/405432
# 170      421997    https://www.airbnb.com/rooms/421997
# ...         ...                                    ...
# 27012  22679407  https://www.airbnb.com/rooms/22679407
# 27020  22689848  https://www.airbnb.com/rooms/22689848
# 27027  22691962  https://www.airbnb.com/rooms/22691962
# 27058  22706892  https://www.airbnb.com/rooms/22706892
# 27065  22708135  https://www.airbnb.com/rooms/22708135
#
#                                                     name    host_id  \
# 16                        Tree Tops Retreat Avalon Beach     311659
# 128                         Ruby's Oasis on Bondi Beach!     201611
# 147                              Coogee Studio Apartment    1937140
# ...

# %%
df[df['beds'] == 0]
# Out:
#              id                            listing_url  \
# 91       264925    https://www.airbnb.com/rooms/264925
# 149      389876    https://www.airbnb.com/rooms/389876
# 169      420647    https://www.airbnb.com/rooms/420647
# 170      421997    https://www.airbnb.com/rooms/421997
# 171      424931    https://www.airbnb.com/rooms/424931
# ...         ...                                    ...
# 25438  22194078  https://www.airbnb.com/rooms/22194078
# 25534  22210446  https://www.airbnb.com/rooms/22210446
# 26377  22394860  https://www.airbnb.com/rooms/22394860
# 26649  22487326  https://www.airbnb.com/rooms/22487326
# 26655  22488321  https://www.airbnb.com/rooms/22488321
#
#                                                     name    host_id  \
# 91                        Stunning North Bondi Beach Pad    1389838
# 149                      Huge Sydney Apartment + Parking    1943399
# 169                  Newtown Darlington Suites-1st. Flr.    2091917
# ...

# %%
df[ (df['beds'] == 0) & (df['bedrooms'] == 0) & (df['bathrooms'] == 0) ]
# Out:
# Empty DataFrame
# Columns: [id, listing_url, name, host_id, host_name, host_since, host_is_superhost, host_identity_verified, street, city, state, country_code, country, latitude, longitude, property_type, room_type, accommodates, bathrooms, bedrooms, beds, bed_type, amenities, square_feet, price, weekly_price, monthly_price, security_deposit, cleaning_fee, guests_included, extra_people, has_availability, number_of_reviews, review_scores_rating, instant_bookable, cancellation_policy, amenities_count]
# Index: []
#
# [0 rows x 37 columns]

# %%
df.query('beds == 0 and bedrooms == 0 and bathrooms == 0')
# Out:
# Empty DataFrame
# Columns: [id, listing_url, name, host_id, host_name, host_since, host_is_superhost, host_identity_verified, street, city, state, country_code, country, latitude, longitude, property_type, room_type, accommodates, bathrooms, bedrooms, beds, bed_type, amenities, square_feet, price, weekly_price, monthly_price, security_deposit, cleaning_fee, guests_included, extra_people, has_availability, number_of_reviews, review_scores_rating, instant_bookable, cancellation_policy, amenities_count]
# Index: []
#
# [0 rows x 37 columns]

# %%
df.query('beds > 2 and bedrooms > 2')
# Out:
#              id                            listing_url  \
# 2         14250     https://www.airbnb.com/rooms/14250
# 6         20865     https://www.airbnb.com/rooms/20865
# 9         45440     https://www.airbnb.com/rooms/45440
# 14        58954     https://www.airbnb.com/rooms/58954
# 15        59297     https://www.airbnb.com/rooms/59297
# ...         ...                                    ...
# 27035  22692669  https://www.airbnb.com/rooms/22692669
# 27046  22695659  https://www.airbnb.com/rooms/22695659
# 27048  22703701  https://www.airbnb.com/rooms/22703701
# 27062  22707609  https://www.airbnb.com/rooms/22707609
# 27068  22709315  https://www.airbnb.com/rooms/22709315
#
#                                                     name    host_id host_name  \
# 2                                    Manly Harbour House      55948     Heidi
# 6                     3 BED HOUSE + 1 BED STUDIO Balmain      64282     Fiona
# ...

# %%
df.query('property_type == "Apartment"')
# Out:
#              id                            listing_url  \
# 0         11156     https://www.airbnb.com/rooms/11156
# 3         14935     https://www.airbnb.com/rooms/14935
# 4         14974     https://www.airbnb.com/rooms/14974
# 5         15253     https://www.airbnb.com/rooms/15253
# 7         26174     https://www.airbnb.com/rooms/26174
# ...         ...                                    ...
# 27059  22707037  https://www.airbnb.com/rooms/22707037
# 27060  22707084  https://www.airbnb.com/rooms/22707084
# 27061  22707243  https://www.airbnb.com/rooms/22707243
# 27064  22708047  https://www.airbnb.com/rooms/22708047
# 27067  22709306  https://www.airbnb.com/rooms/22709306
#
#                                                     name    host_id host_name  \
# 0                                   An Oasis in the City      40855   Colleen
# 3                 Eco-conscious Travellers: Private Room      58796     Kevin
# ...

# %%
df['has_availability']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 27065    1
# 27066    1
# 27067    1
# 27068    1
# 27069    1
# Name: has_availability, Length: 27070, dtype: int64

# %%
df['has_availability'].unique()
# Out:
# array([1])

# %%
df['has_availability'].std()
# Out:
# 0.0

# %%
df['has_availability'].var()
# Out:
# 0.0

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'country', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'has_availability', 'number_of_reviews',
#        'review_scores_rating', 'instant_bookable', 'cancellation_policy',
#        'amenities_count'],
#       dtype='object')

# %%
df.drop('has_availability', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'country', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'number_of_reviews', 'review_scores_rating',
#        'instant_bookable', 'cancellation_policy', 'amenities_count'],
#       dtype='object')

# %%
df.describe(include=object)
# Out:
#                                listing_url               name host_name  \
# count                                27070              27056     27035
# unique                               27070              26556      6398
# top     https://www.airbnb.com/rooms/11156  Bondi Beach House     David
# freq                                     1                 13       287
#
#        host_since host_is_superhost host_identity_verified  \
# count       27035             27035                  27035
# unique       2590                 2                      2
# top      10/07/13                 f                      f
# freq          157             23616                  14323
#
#                              street         city  state country_code  ...  \
# count                         27070        27037  27061        27070  ...
# unique                          773          741     16            1  ...
# top     Bondi Beach, NSW, Australia  Bondi Beach    NSW           AU  ...
# ...

# %%
df['host_is_superhost'].value_counts()
# Out:
# host_is_superhost
# f    23616
# t     3419
# Name: count, dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# Australia    27070
# Name: count, dtype: int64

# %%
df.drop('country', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_since',
#        'host_is_superhost', 'host_identity_verified', 'street', 'city',
#        'state', 'country_code', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'number_of_reviews', 'review_scores_rating',
#        'instant_bookable', 'cancellation_policy', 'amenities_count'],
#       dtype='object')

# %%
# without dollar
df['price']
# Out:
# 0         $65.00
# 1         $98.00
# 2        $469.00
# 3         $63.00
# 4         $39.00
#            ...
# 27065    $101.00
# 27066     $40.00
# 27067    $169.00
# 27068     $98.00
# 27069    $119.00
# Name: price, Length: 27070, dtype: object

# %%
type(df['price'].iloc[0])
# Out:
# str

# %%
df['price'].iloc[0].replace('$', '')
# Out:
# '65.00 '

# %%
df['price'].iloc[0].replace('$', '').strip()
# Out:
# '65.00'

# %%
float(df['price'].iloc[0].replace('$', '').strip())
# Out:
# 65.0

# %%
def convert_price_to_float(price_in_str):
    return float(price_in_str.replace('$', '').replace(',', '').strip())

# %%
df['price'].apply(convert_price_to_float)
# Out:
# 0         65.0
# 1         98.0
# 2        469.0
# 3         63.0
# 4         39.0
#          ...
# 27065    101.0
# 27066     40.0
# 27067    169.0
# 27068     98.0
# 27069    119.0
# Name: price, Length: 27070, dtype: float64

# %%
df['price'] = df['price'].apply(convert_price_to_float)

# %%
df['cleaning_fee']
# Out:
# 0             NaN
# 1         $55.00
# 2        $100.00
# 3             NaN
# 4             NaN
#            ...
# 27065      $0.00
# 27066         NaN
# 27067     $80.00
# 27068    $120.00
# 27069     $50.00
# Name: cleaning_fee, Length: 27070, dtype: object

# %%
def convert_price_to_float(price_in_str):
    if isinstance(price_in_str, str):
        return float(price_in_str.replace('$', '').replace(',', '').strip())
    else:
        return price_in_str

# %%
df['cleaning_fee'] = df['cleaning_fee'].apply(convert_price_to_float)

# %%
df['cleaning_fee']
# Out:
# 0          NaN
# 1         55.0
# 2        100.0
# 3          NaN
# 4          NaN
#          ...
# 27065      0.0
# 27066      NaN
# 27067     80.0
# 27068    120.0
# 27069     50.0
# Name: cleaning_fee, Length: 27070, dtype: float64

# %%
df['host_since']
# Out:
# 0        23/09/09
# 1        14/05/09
# 2        20/11/09
# 3        30/11/09
# 4        30/11/09
#            ...
# 27065    16/02/17
# 27066    12/01/18
# 27067    11/01/18
# 27068    13/01/18
# 27069    13/12/14
# Name: host_since, Length: 27070, dtype: object

# %%
df['host_since'].iloc[0]
# Out:
# '23/09/09'

# %%
pd.to_datetime(df['host_since'])
# Out:
# /var/folders/yv/_ddlvjkn6k11_jp7sl8jcy500000gn/T/ipykernel_52859/2993864240.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df['host_since'])
# 0       2009-09-23
# 1       2009-05-14
# 2       2009-11-20
# 3       2009-11-30
# 4       2009-11-30
#            ...
# 27065   2017-02-16
# 27066   2018-12-01
# 27067   2018-11-01
# 27068   2018-01-13
# 27069   2014-12-13
# Name: host_since, Length: 27070, dtype: datetime64[ns]

# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
df['host_since'] = pd.to_datetime(df['host_since'])

# %%
df['host_since']
# Out:
# 0       2009-09-23
# 1       2009-05-14
# 2       2009-11-20
# 3       2009-11-30
# 4       2009-11-30
#            ...
# 27065   2017-02-16
# 27066   2018-12-01
# 27067   2018-11-01
# 27068   2018-01-13
# 27069   2014-12-13
# Name: host_since, Length: 27070, dtype: datetime64[ns]

# %%
df.isna().sum()
# Out:
# id                            0
# listing_url                   0
# name                         14
# host_id                       0
# host_name                    35
# host_since                   35
# host_is_superhost            35
# host_identity_verified       35
# street                        0
# city                         33
# state                         9
# country_code                  0
# latitude                      0
# longitude                     0
# property_type                 0
# room_type                     0
# accommodates                  0
# bathrooms                    22
# bedrooms                      8
# beds                         33
# bed_type                      0
# amenities                     0
# square_feet               26814
# price                         0
# weekly_price              23150
# monthly_price             24695
# security_deposit          10348
# cleaning_fee               7820
# guests_included               0
# ...

# %%
missing_values = df.isna().sum()

# %%
missing_values[missing_values > 0]
# Out:
# name                         14
# host_name                    35
# host_since                   35
# host_is_superhost            35
# host_identity_verified       35
# city                         33
# state                         9
# bathrooms                    22
# bedrooms                      8
# beds                         33
# square_feet               26814
# weekly_price              23150
# monthly_price             24695
# security_deposit          10348
# cleaning_fee               7820
# review_scores_rating       7558
# dtype: int64

# %%
missing_values[missing_values > 0] / len(df) * 100
# Out:
# name                       0.051718
# host_name                  0.129294
# host_since                 0.129294
# host_is_superhost          0.129294
# host_identity_verified     0.129294
# city                       0.121906
# state                      0.033247
# bathrooms                  0.081271
# bedrooms                   0.029553
# beds                       0.121906
# square_feet               99.054304
# weekly_price              85.519025
# monthly_price             91.226450
# security_deposit          38.226819
# cleaning_fee              28.888068
# review_scores_rating      27.920207
# dtype: float64

# %%
len(df)
# Out:
# 27070

# %%
sns.heatmap(df.isna())
plt.show()

# %%
sns.heatmap(df.isna(), cmap='coolwarm')
plt.show()

# %%
sns.heatmap(df.isna(), cmap='viridis')
plt.show()
